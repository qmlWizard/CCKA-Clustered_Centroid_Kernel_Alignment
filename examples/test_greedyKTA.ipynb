# %%
from ccka.models.kernel import KernelModel
from ccka.circuits.angleEmbeddingKernel import quackEmbeddingCircuit
from ccka.aligner.kta import greedyKTA
import pennylane as qml
import jax
import jax.numpy as jnp

# %%
data = jnp.load('../data/checkerboard_dataset.npy', allow_pickle=True).item()
X = jnp.asarray(data['x_train'])
y = jnp.asarray(data['y_train'])
N, D = X.shape
x1 = jnp.repeat(X, N, axis=0)      # (N*N, D)
x2 = jnp.tile(X, (N, 1))

# %%
kernel = quackEmbeddingCircuit(
                                num_qubits = 5,
                                reps = 6,
                                reupload = True
                        )
init_weights = kernel.init_weights()
model = KernelModel(circuit = kernel)

# %%
aligner = greedyKTA(
                    kernel_model= model,
                    data = X,
                    labels = y,
                    matrix_type='regular', #
                    split_size=0.5,
                    greedy_samples= 4,
                    landmark_points=10,
                    learning_rate=0.2,
                    optimizer= 'adam',
                    epochs=500
)

# %%
history = aligner.align()
# Out:
# Aligning Kernel with Full Kernel KTA:   0%|          | 0/500 [00:00<?, ?it/s]
# Greedy Samples:  [[0.64989895 0.40614605]
#  [0.09843735 0.16090852]
#  [0.15324463 0.0783006 ]
#  [0.85931826 0.3493472 ]] [-1  1  1  1]
# Aligning Kernel with Full Kernel KTA:   0%|          | 0/500 [00:18<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 history = aligner.align()
#
# File ~/Study/CCKA-Clustered_Centroid_Kernel_Alignment/ccka/aligner/kta.py:800, in greedyKTA.align(self)
#     797 self.weights = ox.apply_updates(self.weights, updates)
#     799 result = self.svm_training(self.xtrain, self.ytrain)
# --> 800 train_accuracy_history.append(result['train_accuracy'])
#     801 test_accuracy_history.append(result['test_accuracy'])
#     802 f1_history.append(result['f1_score'])
#
# TypeError: tuple indices must be integers or slices, not str
